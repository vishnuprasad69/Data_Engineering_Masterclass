# %% [markdown]
# # Python Master Assessment: Comprehensive Final Exam 🎓
# This assessment covers all 10 core modules we have prepared. It is designed to test both theoretical knowledge and practical coding ability.

# %% [markdown]
# ## Part 1: Logic & Data Structures
# **Q1.** Write a single line of code (Comprehension) to create a list of squares for only the even numbers between 1 and 20.
#
# **Q2.** What is the primary difference between a Generator and a List in terms of memory usage?

# %% [markdown]
# ## Part 2: Object-Oriented Programming (OOP)
# **Q3.** Explain the 'Diamond Problem' in Multiple Inheritance and how Python's MRO resolves it.
#
# **Q4.** Implement a class `Circle` with a property `radius`. Ensure that setting a negative radius raises a `ValueError` (Encapsulation).

# %% [markdown]
# ## Part 3: Functions, Scopes & Decorators
# **Q5.** In the LEGB rule, what does 'Enclosing' scope refer to?
#
# **Q6.** Create a decorator `@debug` that prints the name of the function being called before executing it.

# %% [markdown]
# ## Part 4: Error Handling & Resource Management
# **Q7.** Why is it considered bad practice to use a bare `except:` block?
#
# **Q8.** Write a context manager using the `__enter__` and `__exit__` methods that prints 'Starting Task' and 'Finished Task'.

# %% [markdown]
# ## Part 5: Advanced Systems (Parallelism & Memory)
# **Q9.** If you are building a tool to compress 10,000 large text files, would you use `threading` or `multiprocessing`? Justify your answer.
#
# **Q10.** How does the Python Garbage Collector detect circular references that reference counting cannot see?

# %% [markdown]
# ---
# **Note:** Take your time to solve these. If you need the solution key for this Master Assessment, feel free to ask!
